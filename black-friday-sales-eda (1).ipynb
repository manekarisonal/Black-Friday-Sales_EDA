# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/black-friday-sales-eda/train.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/black-friday-sales-eda/train.csv')

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df.fillna(0,inplace = True)
df
# Out:
#         User_ID Product_ID  Sex    Age  Occupation City_Category  \
# 0       1000001  P00069042    1   0-17          10             A
# 1       1000001  P00248942    1   0-17          10             A
# 2       1000001  P00087842    1   0-17          10             A
# 3       1000001  P00085442    1   0-17          10             A
# 4       1000002  P00285442    0    55+          16             C
# ...         ...        ...  ...    ...         ...           ...
# 550063  1006033  P00372445    0  51-55          13             B
# 550064  1006035  P00375436    1  26-35           1             C
# 550065  1006036  P00375436    1  26-35          15             B
# 550066  1006038  P00375436    1    55+           1             C
# 550067  1006039  P00371644    1  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529])

# %%
df['Product_ID'].unique()
# Out:
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00370293',
#        'P00371644', 'P00370853'], dtype=object)

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1])

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19])

# %%
df['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
df['Purchase'].unique()
# Out:
# array([ 8370, 15200,  1422, ...,   135,   123,   613])

# %%
# %matplotlib inline
import seaborn as sns

# %%
a = df.groupby('City_Category').agg({'Purchase':'mean'}).head(4)
a
# Out:
#                   Purchase
# City_Category
# A              8911.939216
# B              9151.300563
# C              9719.920993

# %%
df.groupby('Age').agg({'Purchase':'mean'})
# Out:
#           Purchase
# Age
# 0-17   8933.464640
# 18-25  9169.663606
# 26-35  9252.690633
# 36-45  9331.350695
# 46-50  9208.625697
# 51-55  9534.808031
# 55+    9336.280459

# %%
df.groupby('Stay_In_Current_City_Years').agg({'Purchase':'mean'})
# Out:
#                                Purchase
# Stay_In_Current_City_Years
# 0                           9180.075123
# 1                           9250.145923
# 2                           9320.429810
# 3                           9286.904119
# 4+                          9275.598872

# %%
df.groupby('Gender').agg({'Purchase':'sum'})
# Out:
#           Purchase
# Gender
# F       1186232642
# M       3909580100

# %%
df.groupby('Occupation').agg({'Purchase':'sum'}).head()
# Out:
#              Purchase
# Occupation
# 0           635406958
# 1           424614144
# 2           238028583
# 3           162002168
# 4           666244484

# %%
df.groupby('Marital_Status').agg({'Purchase':'sum'}).head()
# Out:
#                   Purchase
# Marital_Status
# 0               3008927447
# 1               2086885295

# %%
# sns.barplot(x = 'Purchase',y = a.index,data = a)

sns.kdeplot(df['Purchase'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Purchase', ylabel='Density'>

# %% [markdown]
# here we are finding density of purchase

# %%
sns.boxplot(x = 'Occupation',y ='Stay_In_Current_City_Years',data = df,palette = 'rainbow' )
# Out:
# <Axes: xlabel='Occupation', ylabel='Stay_In_Current_City_Years'>

# %% [markdown]
# Here we are finding min and max valuese by comparing occupation & stay in current city years

# %%
sns.boxplot(data = df,palette = 'rainbow',orient = 'h')
# Out:
# <Axes: >

# %% [markdown]
# finding min and max values of all columns

# %%
df.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17          10             A
# 6       1000004  P00184942      M  46-50           7             B
# 13      1000005  P00145042      M  26-35          20             A
# 14      1000006  P00231342      F  51-55           9             A
# 16      1000006   P0096642      F  51-55           9             A
# ...         ...        ...    ...    ...         ...           ...
# 545902  1006039  P00064042      F  46-50           0             B
# 545904  1006040  P00081142      M  26-35           6             B
# 545907  1006040  P00277642      M  26-35           6             B
# 545908  1006040  P00127642      M  26-35           6             B
# 545914  1006040  P00217442      M  26-35           6             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2               0                   1
# ...

# %% [markdown]
# removing null value

# %%
df['Gender'] = df['Gender'].map({'M':0,'F':1})
df["Gender"]
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         0
#          ..
# 550063    0
# 550064    1
# 550065    1
# 550066    1
# 550067    1
# Name: Gender, Length: 550068, dtype: int64

# %% [markdown]
# here we are converting categorical data into integer using map function

# %%
df['Age'] = df['Age'].map({'0-17':15,'46-50':45})
df
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  15.0          10             A
# 1       1000001  P00248942      F  15.0          10             A
# 2       1000001  P00087842      F  15.0          10             A
# 3       1000001  P00085442      F  15.0          10             A
# 4       1000002  P00285442      M   NaN          16             C
# ...         ...        ...    ...   ...         ...           ...
# 550063  1006033  P00372445      M   NaN          13             B
# 550064  1006035  P00375436      F   NaN           1             C
# 550065  1006036  P00375436      F   NaN          15             B
# 550066  1006038  P00375436      F   NaN           1             C
# 550067  1006039  P00371644      F  45.0           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.rename(columns = {'Gender':'Sex'},inplace = True)
df
# Out:
#         User_ID Product_ID Sex    Age  Occupation City_Category  \
# 0       1000001  P00069042   F   0-17          10             A
# 1       1000001  P00248942   F   0-17          10             A
# 2       1000001  P00087842   F   0-17          10             A
# 3       1000001  P00085442   F   0-17          10             A
# 4       1000002  P00285442   M    55+          16             C
# ...         ...        ...  ..    ...         ...           ...
# 550063  1006033  P00372445   M  51-55          13             B
# 550064  1006035  P00375436   F  26-35           1             C
# 550065  1006036  P00375436   F  26-35          15             B
# 550066  1006038  P00375436   F    55+           1             C
# 550067  1006039  P00371644   F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %% [markdown]
# remaing the column name

# %%
df['User_ID'].count()
# Out:
# 550068

# %%
import seaborn as sns

# %%
df['Sex']
sns.countplot(x = 'Sex',data = df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# here we are visualizing Sex column by using countplot

# %%
df['Age']
sns.countplot(x = 'Age',data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# here we are visualizing Age column by using countplot

# %%
df['Occupation']
sns.countplot(x = 'Occupation',data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %% [markdown]
# here we are visualizing Occupation column by using countplot

# %%
df['City_Category']
sns.countplot(x = 'City_Category',data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %% [markdown]
# here we are visualizing City_Category column by using countplot

# %%
df['Stay_In_Current_City_Years']
sns.countplot(x = 'Stay_In_Current_City_Years',data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %% [markdown]
# here we are visualizing Stay_In_Current_City_Years column by using countplot

# %%
df['Marital_Status']
sns.countplot(x = 'Marital_Status',data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %% [markdown]
# here we are visualizing Marital_Status column by using countplot

# %%
df['Product_Category_1']
sns.countplot(x = 'Product_Category_1',data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %% [markdown]
# here we are visualizing Product_Category_1 column by using countplot

# %%
df['Product_Category_2']
sns.countplot(x = 'Product_Category_2',data = df)
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='count'>

# %% [markdown]
# here we are visualizing Product_Category_2 column by using countplot

# %%
df['Product_Category_3']
sns.countplot(x = 'Product_Category_3',data = df)
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='count'>

# %% [markdown]
# here we are visualizing Product_Category_3 column by using countplot

# %%
df['Purchase']
sns.kdeplot(x = 'Purchase',data = df)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Purchase', ylabel='Density'>

# %% [markdown]
# here we are finding density of purchase

# %%
a = df.groupby('Age').agg({'Purchase':'mean'})
a
# Out:
#           Purchase
# Age
# 0-17   8933.464640
# 18-25  9169.663606
# 26-35  9252.690633
# 36-45  9331.350695
# 46-50  9208.625697
# 51-55  9534.808031
# 55+    9336.280459

# %%
a.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# According to the age of customers purchase rate is plotted

# %%
sns.barplot(x = a.index, y = a['Purchase'])
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# According to the age of customers purchase rate is plotted

# %%
b = df.groupby('Occupation').agg({'Purchase':'mean'}).head(10)
b
# Out:
#                Purchase
# Occupation
# 0           9124.428588
# 1           8953.193270
# 2           8952.481683
# 3           9178.593088
# 4           9213.980251
# 5           9333.149298
# 6           9256.535691
# 7           9425.728223
# 8           9532.592497
# 9           8637.743761

# %%
sns.barplot(x = b.index,y = b['Purchase'])
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %% [markdown]
# According to the occupation purchase is plotted

# %%
c = df.groupby('Product_Category_1').agg({'Purchase':'mean'}).head(10)
c
# Out:
#                         Purchase
# Product_Category_1
# 1                   13606.218596
# 2                   11251.935384
# 3                   10096.705734
# 4                    2329.659491
# 5                    6240.088178
# 6                   15838.478550
# 7                   16365.689600
# 8                    7498.958078
# 9                   15537.375610
# 10                  19675.570927

# %%
sns.barplot(x = c.index,y = c['Purchase'])
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %% [markdown]
# According to the Product_Category_1 purchase is plotted

# %%
d = df.groupby('Product_Category_2').agg({'Purchase':'mean'}).head(10)
d
# Out:
#                         Purchase
# Product_Category_2
# 2.0                 13619.356401
# 3.0                 11235.359570
# 4.0                 10215.192001
# 5.0                  9027.821574
# 6.0                 11503.551379
# 7.0                  6884.683706
# 8.0                 10273.259518
# 9.0                  7277.006851
# 10.0                15648.729543
# 11.0                 8940.580515

# %%
sns.barplot(x = d.index,y = d['Purchase'])
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='Purchase'>

# %% [markdown]
# According to the Product_Category_2 purchase is plotted

# %%
e = df.groupby('Product_Category_3').agg({'Purchase':'mean'}).head(10)
e
# Out:
#                         Purchase
# Product_Category_3
# 3.0                 13939.696574
# 4.0                  9794.386667
# 5.0                 12117.786889
# 6.0                 13194.311043
# 8.0                 13024.918882
# 9.0                 10431.697210
# 10.0                13505.813441
# 11.0                12091.437673
# 12.0                 8715.512762
# 13.0                13185.118703

# %%
sns.barplot(x = e.index,y = e['Purchase'])
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='Purchase'>

# %% [markdown]
# According to the Product_Category_3 purchase is plotted

# %%
import matplotlib.pyplot as plt
x1=df["City_Category"].value_counts()
x1
# Out:
# City_Category
# B    231173
# C    171175
# A    147720
# Name: count, dtype: int64

# %%
import seaborn as sns
keys=['A', 'B', 'C']

plt.pie(x = x1,data = df,labels=keys, autopct='%.0f%%');

# %% [markdown]
# here we are creating City category pie chart according to the percentage

# %%
z = df['Age'].value_counts()
z
# Out:
# Age
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: count, dtype: int64

# %%
keys = ['0-17','55+','51_55','46_50','18_25','36_45','26_35']
plt.pie(x= z,data = df,labels = keys,autopct='%.0f%%');

# %% [markdown]
# In this pie chart according to the age will see the percentage

# %%
y = df['Gender'].value_counts()
y
# Out:
# Gender
# M    414259
# F    135809
# Name: count, dtype: int64

# %%
keys = ['M','F']
plt.pie(x = y,data = df,autopct='%.0f%%',labels = keys);

# %% [markdown]
# here we can clearly observe male percentage is greaterthan female
